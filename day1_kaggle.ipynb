# %% [markdown]
# <a href="https://colab.research.google.com/github/arpitcodelab/GenAi_course/blob/main/day1_kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -u -p "google-genai==1.7.0"
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: -u

# %%
from google import genai
from google.genai import types
from IPython.display import Markdown, display ,HTML

# %%
from google.api_core import retry
is_retriable = lambda e: (isinstance(e, genai.errors.APIError) and e.code in {429, 503})
genai.models.Models.generate_content = retry.Retry(
    predicate=is_retriable)(genai.models.Models.generate_content)

# %%
import getpass
from google import genai

# 🔐 Ask user to input the API key securely
GOOGLE_API_KEY = getpass.getpass("Enter your Google API key: ")

# ✅ Create the client with the key
client = genai.Client(api_key=GOOGLE_API_KEY)
# Out:
# Enter your Google API key: ··········

# %%
response = client.models.generate_content(
    model="gemini-2.0-flash",
    contents="explain me ai in 2 paragraphs."
)
print(response.text)
# Out:
# Artificial intelligence (AI) is essentially about creating machines that can perform tasks that typically require human intelligence. This involves programming computers to learn, reason, solve problems, understand language, and even perceive the world around them. AI is not about replicating human consciousness, but rather about mimicking or augmenting our cognitive abilities using algorithms and statistical models. The ultimate goal is to build systems that can automate processes, analyze vast amounts of data, and make intelligent decisions with minimal human intervention.
#
# AI manifests in a wide range of applications, from virtual assistants like Siri and Alexa to self-driving cars and medical diagnosis tools. It relies on various techniques like machine learning, deep learning, natural language processing, and computer vision. These techniques enable AI systems to learn from data, identify patterns, and make predictions, ultimately leading to more efficient, accurate, and personalized solutions across diverse industries. The field is constantly evolving, with ongoing research focused on developing more sophisticated and adaptable AI that can handle increasingly complex challenges.

# %%
Markdown(response.text)
# Out:
# Artificial intelligence (AI) is essentially about creating machines that can perform tasks that typically require human intelligence. This involves programming computers to learn, reason, solve problems, understand language, and even perceive the world around them. AI is not about replicating human consciousness, but rather about mimicking or augmenting our cognitive abilities using algorithms and statistical models. The ultimate goal is to build systems that can automate processes, analyze vast amounts of data, and make intelligent decisions with minimal human intervention.
#
# AI manifests in a wide range of applications, from virtual assistants like Siri and Alexa to self-driving cars and medical diagnosis tools. It relies on various techniques like machine learning, deep learning, natural language processing, and computer vision. These techniques enable AI systems to learn from data, identify patterns, and make predictions, ultimately leading to more efficient, accurate, and personalized solutions across diverse industries. The field is constantly evolving, with ongoing research focused on developing more sophisticated and adaptable AI that can handle increasingly complex challenges.

# %%
chat = client.chats.create(model="gemini-2.0-flash" , history=[])
response = chat.send_message("i am arpit.")
print(response.text)
# Out:
# Okay, Arpit. It's nice to meet you. How can I help you today?

# %%
response = chat.send_message("what is my name?")
print(response.text)
Markdown(response.text)
# Out:
# Your name is Arpit. You just told me that.
# Your name is Arpit. You just told me that.
